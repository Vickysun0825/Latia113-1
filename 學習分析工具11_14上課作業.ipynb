# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)   # 產生 0～10 總共 100 連續數字
y = 4 + 2 * np.sin(2 * x)     # 使用 NumPy 的廣播方式，產生sin 數值的陣列y
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)  # 繪製折線圖
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),  # 設定座標軸
ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img  # 用於讀取圖像
import os  # 如果需要管理檔案系統可以保留此匯入，否則可以刪除

# 確保圖像檔案 'aa.jpg' 存在於執行程式碼的目錄下
if os.path.exists('aa.jpg'):
    image = img.imread('aa.jpg')  # 讀取圖像
    plt.figure(figsize=(10, 10))  # 設定圖表大小
    plt.imshow(image)  # 顯示圖像
    plt.axis('off')  # 隱藏坐標軸（可選）
    plt.show()  # 顯示圖表
else:
    print("Error: File 'aa.jpg' not found.")  # 提供有意義的錯誤提示
# Out:
# Error: File 'aa.jpg' not found.

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')   # 設定為 3D 圖表
x = range(5)
y = [1,5,8,4,6]
ax.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
# 畫出顏色紅色、圓形錨點、虛線、粗細2、資料點大小6 的線條
#plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
plt.plot(x)
plt.show()

# %%
import numpy as np
import pandas as pd
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.235536  0.014899 -0.136297  0.631183
# 2013-01-02  1.324916 -2.554371 -1.939426 -0.108683
# 2013-01-03 -0.519389  0.624034  1.360116 -1.531794
# 2013-01-04 -0.064081  1.557834 -1.946983  1.564133
# 2013-01-05  0.607078 -0.634193  1.675747 -1.025645
# ...              ...       ...       ...       ...
# 2013-04-06 -0.430647 -1.544361 -0.578080  0.983745
# 2013-04-07 -0.784573  1.219989 -0.479207 -0.951812
# 2013-04-08 -1.645593  0.651993  0.332999 -2.106778
# 2013-04-09 -0.369404  0.269493  1.145956  0.663107
# 2013-04-10  0.130247  0.752764 -1.081580  0.338374
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# 定義 x 和 y 數據
x = [0, 1, 2, 3, 4, 5]  # x 軸數據
y = [0, 1, 4, 9, 16, 25]  # y 軸數據

# 繪製折線圖，使用紅色、圓形錨點、虛線、線條寬度2、資料點大小6
plt.plot(x, y, color='r', marker='o', linestyle='--', linewidth=2, markersize=6)

# 顯示圖表
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
h = [10,20,30,40,50]
color = ['r','b','g','y','m'] # 顏色數據
label = ['a','b','c','d','e'] # 標籤數據
plt.bar(x,h,color=color,tick_label=label,width=0.5) # 加入顏色、標籤和寬度參數
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
plt.pie(x, radius=1.5, labels=x)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')
x = [2,4,6,8,10]
y = 10
z = 1
ax.bar3d(x,y,z,dx=1,dy=1,dz=[1,2,3,4,5])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # 用於繪製 3D 圖

# 生成資料
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 計算每列的總和，作為示例
column_totals = df.sum()

# 1. 繪製長條圖
plt.figure(figsize=(8, 6))
plt.bar(column_totals.index, column_totals.values, color='skyblue')
plt.title("Column Totals - Bar Chart")
plt.xlabel("Columns")
plt.ylabel("Total")
plt.show()

# 2. 繪製圓餅圖
plt.figure(figsize=(8, 6))
plt.pie(column_totals.values, labels=column_totals.index, autopct='%1.1f%%', startangle=90, colors=['red', 'green', 'blue', 'orange'])
plt.title("Column Totals - Pie Chart")
plt.axis('equal')  # 確保圓形
plt.show()

# 3. 繪製 3D 柱狀圖
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 3D 資料
x = np.arange(len(column_totals))  # X 軸位置
y = np.zeros(len(column_totals))  # Y 軸基準為 0
z = np.zeros(len(column_totals))  # Z 軸基準為 0
dx = np.ones(len(column_totals))  # X 軸柱寬度
dy = np.ones(len(column_totals))  # Y 軸柱寬度
dz = column_totals.values  # 柱的高度對應總和

# 繪製 3D 柱狀圖
ax.bar3d(x, y, z, dx, dy, dz, color=['r', 'g', 'b', 'orange'])
ax.set_xticks(x)
ax.set_xticklabels(column_totals.index)
ax.set_title("Column Totals - 3D Bar Chart")
ax.set_xlabel("Columns")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Total")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
 # Generate a correlation matrix for the selected columns
corrMatrix = df.corr()
 # Plot the correlation matrix using a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
import numpy as np
from scipy import stats
 # 三個班學生的成績
group1 = [85, 86, 88, 75, 78, 94]
group2 = [92, 94, 89, 96, 93, 95, 76, 50]
group3 = [78, 81, 79, 84, 77, 80]
 # 使用scipy.stats.f_oneway 進行單因子 ANOVA 檢定
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
 # 輸出結果
print("F 統計量:", f_statistic)
print("p-value:", p_value)
 # 解釋結果
alpha = 0.05  # 顯著性水平
if p_value < alpha:
 print("拒絕原假設：不同組別之間的均值存在顯著差異。")
else:
 print("未能拒絕原假設：不同組別之間的均值沒有顯著差異。")
# Out:
# F 統計量: 0.5135486690669941
# p-value: 0.6073604385431465
# 未能拒絕原假設：不同組別之間的均值沒有顯著差異。

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
 # 創建數據集
data = {
 'Score': [85, 86, 88, 75, 78, 94, 92, 94, 89, 96, 93, 95, 78, 81,
79, 84, 77, 80],
 'Method': ['A', 'A', 'A', 'A', 'A', 'A',  # 教學方法 A
 'B', 'B', 'B', 'B', 'B', 'B',  # 教學方法 B
 'C', 'C', 'C', 'C', 'C', 'C']  # 教學方法 C
 }
 # 將數據轉換為DataFrame
df = pd.DataFrame(data)
 # 使用statsmodels 中的ols 方法進行單因子ANOVA 分析
model = ols('Score ~ C(Method)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
 # 輸出ANOVA 表
print(anova_table)
# Out:
#                sum_sq    df          F    PR(>F)
# C(Method)  552.111111   2.0  13.848941  0.000391
# Residual   299.000000  15.0        NaN       NaN
